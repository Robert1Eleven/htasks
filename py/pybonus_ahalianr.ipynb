# %% [markdown]
# # Программирование на Python
#
# # Бонусное задание. Работа с API YouTube.

# %% [markdown]
# **1. Подгрузите необходимые модули, своими словами поясните, зачем они нужны. Обратитесь к API YouTube, используя свой API key.**
#
# *Доброе напоминание: когда будете сдавать работу, замените свой API key на фразу ВАШ КЛЮЧ*

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in d:\programs\anaconda\lib\site-packages (2.80.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in d:\programs\anaconda\lib\site-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\programs\anaconda\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in d:\programs\anaconda\lib\site-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in d:\programs\anaconda\lib\site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in d:\programs\anaconda\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in d:\programs\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in d:\programs\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.22.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in d:\programs\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\programs\anaconda\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\programs\anaconda\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in d:\programs\anaconda\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\programs\anaconda\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\programs\anaconda\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\programs\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programs\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programs\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in d:\programs\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programs\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)

# %%
from googleapiclient.discovery import build

api_key = "AIzaSyAHwtJHOg8KhL3Rcu6QejOnIPQ40vJsLi8"
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# **2. Создайте поисковый запрос с помощью метода `.search()` по интересующей вас теме с параметром `maxResults = 50`**

# %%
result = youtube.search().list(
    q='yandex api',
    part='id,snippet',
    maxResults=50
).execute()
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'K7d9Z69oSbN4r7S68Bs2pIQyjo4',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'RU',
#  'pageInfo': {'totalResults': 957459, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'BtuPgADMC62UW_G6ca2f_2EYPYg',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLRdm4iTnaFk1GEGBmnCL8jvHBCSL-0D3R'},
#    'snippet': {'publishedAt': '2018-07-11T17:08:55Z',
#     'channelId': 'UCKT0HZHb6a24hyyP9exdBIg',
#     'title': 'Yandex Maps API',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Default C',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-07-11T17:08:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gigUStQPS_XGjIf1demjn3n8bRk',
#    'id': {'kind': 'youtube#video', 'videoId': 'JT5XTA2zjTU'},
#    'snippet': {'publishedAt': '2021-08-17T14:00:06Z',
#     'channelId': 'UCxJyCit95jsb-JLE3kXnq1Q',
#     'title': '№1. Создание Яндекс.карты на сайт. Базовое подключение',
#     'description': 'Привет! Этим видео стартует новая рубрика - про яндекс карты. В нескольких видео покажу, как ее создавать, добавлять ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JT5XTA2zjTU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JT5XTA2zjTU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JT5XTA2zjTU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MaxGraph - cайты как страсть',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-17T14:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '25dRpNYDtqluUEpuK5tm9YCunck',
#    'id': {'kind': 'youtube#video', 'videoId': 'vbGYz-YYM5s'},
#    'snippet': {'publishedAt': '2013-09-05T13:33:26Z',
#     'channelId': 'UCixlrqz8w-oa4UzdKyHLMaA',
#     'title': 'Введение в JavaScript API Яндекс.Карт',
#     'description': 'Онлайн-семинар для тех, кто только-только начинает программировать и хочет изучить JavaScript API Яндекс.Карт ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vbGYz-YYM5s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vbGYz-YYM5s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vbGYz-YYM5s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Яндекс',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-09-05T13:33:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Yj7xdRQXygSzbQ0xLXonu2d43RQ',
#    'id': {'kind': 'youtube#video', 'videoId': '_xCh8LHEJJA'},
#    'snippet': {'publishedAt': '2022-03-26T04:58:14Z',
#     'channelId': 'UCzwAJyw4MO4bAUMOs64X4cw',
#     'title': 'Как получить токен API Яндекс Метрики',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Веб-программист. Дмитрий Ченгаев.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-26T04:58:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fHyPYfzCXwerXUe9DdCpe-4e-LM',
#    'id': {'kind': 'youtube#video', 'videoId': 'BZ4aTQDJ28Q'},
#    'snippet': {'publishedAt': '2019-08-13T11:47:45Z',
#     'channelId': 'UCKQxku4Q5tivvM1ihC_zlwA',
#     'title': 'Выгрузка данных из API Яндекс Директ в CSV с помощью Python3: 30 млн строк.',
#     'description': 'Решение по выгрузке большого объема данных из API Яндекс Директ через коннектор на Python, и последующая ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BZ4aTQDJ28Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BZ4aTQDJ28Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BZ4aTQDJ28Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jam Agency — eCommerce marketing engineering',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-08-13T11:47:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dcZurD_i-k14EHwLibUY6vpI49Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'ltb4-tROtLk'},
#    'snippet': {'publishedAt': '2017-04-26T06:56:06Z',
#     'channelId': 'UC99_v_T0CTEsYiY2O6YsvOA',
#     'title': 'Yandex Карты. API',
#     'description': 'Наш сайт - http://flexatel.ru/ В данном видео разобраны основные возможности API Yandex карт. Полезные ссылки: API ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ltb4-tROtLk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Основы программирования для географов',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-26T06:56:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i00aJiahNr9IsQy1gkPwxYZl_O8',
#    'id': {'kind': 'youtube#video', 'videoId': 'QkNaBL4ky4U'},
#    'snippet': {'publishedAt': '2022-10-25T10:02:33Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Разработка пользовательских интеграций для API Gateway',
#     'description': 'На этом вебинаре мы рассказали, как сделать пользовательскую интеграцию сервиса API Gateway с базой данных YDB в ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-25T10:02:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '87ia5sRCGe4Iy2uBpXlgV4HMTWg',
#    'id': {'kind': 'youtube#video', 'videoId': 'X9tDjQitINI'},
#    'snippet': {'publishedAt': '2021-10-06T06:52:44Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Yandex Speechkit + Python = Синтез озвучки из текста, API',
#     'description': 'Yandex Speechkit - сервис для создания аудио контента из текста. То что называется Text-To-Speech (tts). Speechkit ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-06T06:52:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jfvleFHUA5R8N3QYi5B5tDypmuM',
#    'id': {'kind': 'youtube#video', 'videoId': 'QkfUqb2XFRw'},
#    'snippet': {'publishedAt': '2017-10-05T18:09:35Z',
#     'channelId': 'UCIIt69f5D44s2cdb9vXQNzA',
#     'title': 'Использование API Яндекс.Карт на сайте',
#     'description': 'Познакомимся с основными компонентами и понятиями API Яндекс. Карт, а также с самим понятием API. Научимся ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QkfUqb2XFRw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QkfUqb2XFRw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QkfUqb2XFRw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'loftblog',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-10-05T18:09:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ClpWV4Ud7AXTqSeFh8FLFPe4Omc',
#    'id': {'kind': 'youtube#video', 'videoId': '1IV9RUDm__w'},
#    'snippet': {'publishedAt': '2020-03-20T09:06:13Z',
#     'channelId': 'UCFR_01HgNXZT4PkYye5nY2w',
#     'title': 'Инструкция: Получение API ключа для Yandex Speech Kit',
#     'description': 'Ключ нужен для настройки модуля умной маршрутизации и генерации речи МИКО. Суть работы модуля в накоплении ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1IV9RUDm__w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1IV9RUDm__w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1IV9RUDm__w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'МИКО - центр разработки программных продуктов',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-03-20T09:06:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6rzY_Fz3hju6YmiqJxNZKFC7pPg',
#    'id': {'kind': 'youtube#video', 'videoId': 'XWa_0sG-e9Q'},
#    'snippet': {'publishedAt': '2022-11-20T11:03:01Z',
#     'channelId': 'UClidydU89-1rOzkyPMhB0hQ',
#     'title': 'Изучаем API сервиса Яндекс.Погода',
#     'description': 'Рассказано и показано как читать API и подключать сервис Яндекс.Погода к конструктору чат-ботов LeadTeh. ✳️ Создай ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Чат-боты от Владимира',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-20T11:03:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kZdEj1LWslXAzshEId0wT7MP_0A',
#    'id': {'kind': 'youtube#video', 'videoId': 'PkjzHDGtabY'},
#    'snippet': {'publishedAt': '2021-10-29T02:53:14Z',
#     'channelId': 'UC2qk1YB5XwCALELrTkoadIA',
#     'title': 'Getting started with Yandex API in kodular | Kodular Tutorial |',
#     'description': 'Getting started with Yandex API in kodular | Kodular Tutorial | Welcome Everyone.... Today i will teach you how to use "Yandex ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PkjzHDGtabY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PkjzHDGtabY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PkjzHDGtabY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodular Tutorial',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-29T02:53:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Kgd0h3nIEgDahdzoJIvRml7YtIQ',
#    'id': {'kind': 'youtube#video', 'videoId': '-xabaUpW0Yw'},
#    'snippet': {'publishedAt': '2014-06-23T13:29:02Z',
#     'channelId': 'UCixlrqz8w-oa4UzdKyHLMaA',
#     'title': 'Полигон REST API Яндекс.Диска',
#     'description': 'Что из себя представляет REST API Диска и как с ним можно «поиграться» прямо из браузера.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-xabaUpW0Yw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-xabaUpW0Yw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-xabaUpW0Yw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Яндекс',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-06-23T13:29:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LNRX0PX20ksYa6aJ_wsxwK06uyQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'w8t4tdtIzYY'},
#    'snippet': {'publishedAt': '2020-02-03T19:19:32Z',
#     'channelId': 'UCCZvBK1iehsrvirDeoQFC2Q',
#     'title': 'API для начинающих. Пример VK. [1/5]',
#     'description': 'Привет. В этом видео речь об аббревиатуре API: что это такое, как используется, показываю примеры VK, Яндекс.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w8t4tdtIzYY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w8t4tdtIzYY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w8t4tdtIzYY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Marlin',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-02-03T19:19:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6eQktgsfAYQ-uW8zOLUDr4DiQoM',
#    'id': {'kind': 'youtube#video', 'videoId': 'vus1x3IIaiI'},
#    'snippet': {'publishedAt': '2021-08-21T11:53:56Z',
#     'channelId': 'UC68QxMh7Gfu_ZDk0KZjSHcQ',
#     'title': 'OAuth авторизация на примере Yandex.Disk с помощью встроенного браузера',
#     'description': 'Пример OAuth авторизации на примере Yandex.Disk с использование Windows Form и встроенного браузера.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vus1x3IIaiI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vus1x3IIaiI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vus1x3IIaiI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'c# учимся вместе',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-21T11:53:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cIT1Qlo30KPARojSvmKCrkIK14M',
#    'id': {'kind': 'youtube#video', 'videoId': 'Px1YyTj1h9M'},
#    'snippet': {'publishedAt': '2021-10-14T09:06:00Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Yandex SpeechKit. Получение ВЕЧНОГО Api Key. TTS на Python.',
#     'description': 'В прошлом видео о Yandex SpeechKit я использовал IAM токен для доступа к API Yandex Cloud. Однако такой токен ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Px1YyTj1h9M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Px1YyTj1h9M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Px1YyTj1h9M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-14T09:06:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X6qf3z_oufHgaLmd0WIeOyeiyIw',
#    'id': {'kind': 'youtube#video', 'videoId': '16tGWx_yuwk'},
#    'snippet': {'publishedAt': '2021-08-24T14:00:09Z',
#     'channelId': 'UCxJyCit95jsb-JLE3kXnq1Q',
#     'title': '№2. Создание Яндекс.карты на сайт. Метки на карте',
#     'description': 'Привет! Этим видео стартует новая рубрика - про яндекс карты. В нескольких видео покажу, как ее создавать, добавлять ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/16tGWx_yuwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/16tGWx_yuwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/16tGWx_yuwk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MaxGraph - cайты как страсть',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-24T14:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_vXp7fFS92NhkO-v5JlkmreL988',
#    'id': {'kind': 'youtube#video', 'videoId': 'rJe5IJsS_ho'},
#    'snippet': {'publishedAt': '2018-11-13T10:56:16Z',
#     'channelId': 'UCMtlICYxr6Dz_PG9_SVqRYQ',
#     'title': '023. Создание модулей для API Яндекс Карт на примере визуализации данных –  Руслан Хуснетдинов',
#     'description': 'Расскажу, как развернуть современную инфраструктуру для разработки модулей и сделать API дружелюбным, а также ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rJe5IJsS_ho/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rJe5IJsS_ho/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rJe5IJsS_ho/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Фронтенд',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-11-13T10:56:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tU8U5jGhxOrigADtLFJsDT5lZ9A',
#    'id': {'kind': 'youtube#video', 'videoId': '0C5hxmqH6-A'},
#    'snippet': {'publishedAt': '2019-11-12T14:32:25Z',
#     'channelId': 'UCzmiWJV2hryO6-IVZGw7cPQ',
#     'title': 'Пример сервиса на GO для работы с Yandex Disk Api',
#     'description': 'Пример простого сервиса на Go для регулярного сохранения бэкапов баз данных на Яндекс Диск Больше материалов - у ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0C5hxmqH6-A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0C5hxmqH6-A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0C5hxmqH6-A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Neuro Lab! Algorithms',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-11-12T14:32:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uOM1ebzqC7ZGshtzsUsVQDaJ1yw',
#    'id': {'kind': 'youtube#video', 'videoId': 'AYIqm4nWB1Y'},
#    'snippet': {'publishedAt': '2022-03-01T15:22:10Z',
#     'channelId': 'UCm3GLiJRtmTR2pfyR2GYuYA',
#     'title': 'FBS Яндекс.Маркет автоматизация 1С: УТ 11 по API',
#     'description': 'Это вводное видео, в котором я рассказываю о базовом функционале нашего модуля и его отличиях от стандартного ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Бюро полезных разработок',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-01T15:22:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Wt6G9zfebk5MBhilarEwz2KNO1g',
#    'id': {'kind': 'youtube#video', 'videoId': 'SYwIFlXg-3w'},
#    'snippet': {'publishedAt': '2022-02-26T08:53:32Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Yandex Cloud Functions 👍 Что это и как использовать? (FaaS, Python)',
#     'description': 'Как ЛЕГКО и БЕСПЛАТНО захостить свой код на Python без знания nginx, gunicorn, django и т.д. ✔️ Как получить HTTPS ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-26T08:53:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zvaunhuIr6KGLTNQMN-SEMI1WWQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'fWnbhsipfGA'},
#    'snippet': {'publishedAt': '2017-02-08T10:45:09Z',
#     'channelId': 'UCaGOrRKj1f-HPF1nyv5JTNA',
#     'title': 'Переводчик на Python Yandex API',
#     'description': 'Yandex Technologies: https://tech.yandex.com.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fWnbhsipfGA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fWnbhsipfGA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fWnbhsipfGA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Евгений Егиоя',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-08T10:45:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5kV1X5fPBwb4POvNGwbNMqGJpqE',
#    'id': {'kind': 'youtube#video', 'videoId': 'O1RpLwsGocc'},
#    'snippet': {'publishedAt': '2021-10-08T14:35:11Z',
#     'channelId': 'UCuXwflbvbldutbD96sPSBmQ',
#     'title': 'Yandex Cloud - машинное обучение: API (Yandex  Translate, Vision, SpeechKit), Yandex Sphere',
#     'description': 'Авторы: Простотина Олеся, Румянцев Александр, Старусев Николай, Фанина Маргарита, Раева Юлия, Марцинкевич ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/O1RpLwsGocc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/O1RpLwsGocc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/O1RpLwsGocc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ITSM Dao. Лекции по IT',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-08T14:35:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0xbJzG3a2UA8E25OjVrChDUUz9M',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ge9-5kUSmbY'},
#    'snippet': {'publishedAt': '2015-04-24T13:47:23Z',
#     'channelId': 'UCSxCTnb99fG69-CDL_kCf6A',
#     'title': '[#javascript] Yandex API кластеры',
#     'description': 'Как создать кластеры? Как отобразить много точек на карте, чтобы ими можно было пользоваться? На эти некоторые ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ge9-5kUSmbY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ge9-5kUSmbY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ge9-5kUSmbY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Dmitry Glazentsov',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-04-24T13:47:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'p6lVShTnHsu71tazgUgNkeev3co',
#    'id': {'kind': 'youtube#video', 'videoId': 'i8sZhvCLzkw'},
#    'snippet': {'publishedAt': '2019-06-10T14:13:51Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': '7. Yandex Data Lens. Визуализация данных на примере Metrika API Logs  – Роман Колеченков',
#     'description': 'Начните работать с базами данных прямо сейчас: https://clck.ru/GVp8w Подписывайтесь и следите за нашими новостями: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i8sZhvCLzkw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i8sZhvCLzkw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i8sZhvCLzkw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-06-10T14:13:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'p0JJ7WFNunC35udl2xLX9FykFDU',
#    'id': {'kind': 'youtube#video', 'videoId': '_-2c_5QdR0Q'},
#    'snippet': {'publishedAt': '2020-12-03T09:36:05Z',
#     'channelId': 'UC3HMW66oQEZiuXF5akyLBng',
#     'title': 'Tilda. Как добавить яндекс и гугл карта | Без ключа для MAPS API',
#     'description': 'Привет мой друг! В этом видео ты узнаешь как добавить яндекс и гугл карта БЕЗ ключа для MAPS API. Приятного ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_-2c_5QdR0Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_-2c_5QdR0Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_-2c_5QdR0Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Макс Куратов',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-03T09:36:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qkfezLotDTaeTloUh5Xg0XeLGjU',
#    'id': {'kind': 'youtube#video', 'videoId': 'U5Dhp6vWyx4'},
#    'snippet': {'publishedAt': '2022-03-01T14:50:19Z',
#     'channelId': 'UCq3bVEw7exNtfuyZ78HHoNQ',
#     'title': 'Instantly Index Content To Search Engines | Google, Bing, and Yandex [2022]',
#     'description': 'Have a blog or website? You publish content daily but your content not Indexing fast. So you want to Index articles instantly? If yes ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Pronay Sarkar',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-01T14:50:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7OJjpYZejf7qK_CSDRX2li7tmaA',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLWVnIRD69wY5y36nWm6eyoF9VeWuQuhic'},
#    'snippet': {'publishedAt': '2021-10-04T15:38:57Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Yandex Cloud',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X9tDjQitINI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-04T15:38:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VtiXlFuqr9vHyJtjgBprZt4qQSQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'fPhVtcpr8HU'},
#    'snippet': {'publishedAt': '2022-12-20T10:52:41Z',
#     'channelId': 'UCm_4eZC2WOW1wXXDCXyNKVg',
#     'title': 'Новое поколение Яндекс Карт: как изменится цифровой город',
#     'description': 'Встречайте детализированные карты, где здания, дороги, деревья и другие объекты выглядят почти как реальные.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fPhVtcpr8HU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fPhVtcpr8HU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fPhVtcpr8HU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Яндекс Карты',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-20T10:52:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7HwUC8nHb0y1A1V4-F5bgHFGLnk',
#    'id': {'kind': 'youtube#video', 'videoId': '65i5lcc2SaU'},
#    'snippet': {'publishedAt': '2021-07-19T10:43:39Z',
#     'channelId': 'UCdldbhAwO16vjnDwACTs5gQ',
#     'title': 'Создаем Telegram-бота по управление ПК голосом (Yandex.SpeechKit + NodeJS)',
#     'description': 'В начале планировал сделать бота для своих личных целей, чтобы отключать компьютер, свет и т.п., но в ходе разработки ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/65i5lcc2SaU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/65i5lcc2SaU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/65i5lcc2SaU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Archakov Blog',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-19T10:43:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eForhij4Rhsw20zmmwdz08NgVvQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'nCW-esaFB9s'},
#    'snippet': {'publishedAt': '2022-07-14T11:00:13Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'TradingView Alerts WebHook + Python = Telegram | with Yandex Cloud Functions and Telegram Bot API',
#     'description': 'В TradingView есть классная штука кот называется Alerts. Алерты особенно классны тем что умеют отправлять WebHook, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-14T11:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'D2Dt6MrIjLukjh07d2YDY77w6aU',
#    'id': {'kind': 'youtube#video', 'videoId': 'XZyQAqvRH8U'},
#    'snippet': {'publishedAt': '2019-12-22T14:33:00Z',
#     'channelId': 'UCvDQnTKnIAbQcabMhq2HlKA',
#     'title': 'Расчет доставки за МКАД на основе API Yandex Maps',
#     'description': 'Для клиента был внедрен функционал расчета стоимости доставки в пределах МКАД и расчет удаленности от МКАД.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XZyQAqvRH8U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XZyQAqvRH8U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XZyQAqvRH8U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Игорь К',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-12-22T14:33:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ysUOAY_BXZA4nLm2bmXBnFWWvQU',
#    'id': {'kind': 'youtube#video', 'videoId': '70qcsoUsPJQ'},
#    'snippet': {'publishedAt': '2021-04-13T09:35:11Z',
#     'channelId': 'UCfxnN0xALQR6OtznIj35ypQ',
#     'title': 'Python + Геолокация = Love',
#     'description': 'Привет друзья! Как работать с геолокацией в Python?! Как работать с картой в Python? Как получить адрес по координатам ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/70qcsoUsPJQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/70qcsoUsPJQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/70qcsoUsPJQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Изучаем мир ИТ / Олег Шпагин / Программирование',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-13T09:35:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zI8NIkUyoAV-1qhAX1WgZqbi1J8',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZQc5kypkUfo'},
#    'snippet': {'publishedAt': '2020-08-28T08:21:24Z',
#     'channelId': 'UCw5pdaP2LoyYa5WbOieTq9w',
#     'title': 'Создание приложения без сервисов Google. Часть 1. Yandex Mapkit 3.',
#     'description': 'Начинаем разработку приложения на картах Yandex Maps В данном видео мы сделаем подготовительные работы.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZQc5kypkUfo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZQc5kypkUfo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZQc5kypkUfo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Руслан Галиев',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-08-28T08:21:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5lEATWrCqSE1yLQCqwWM2-connQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'AgwhiHLu2H4'},
#    'snippet': {'publishedAt': '2018-08-27T14:28:48Z',
#     'channelId': 'UCvuY904el7JvBlPbdqbfguw',
#     'title': 'Работа с Google Maps API / Создание своей карты на JavaScript',
#     'description': 'Ссылка на регистрацию на интенсив - https://bit.ly/2OY0HaV Google API невероятно большой и позволяет делать ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AgwhiHLu2H4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AgwhiHLu2H4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AgwhiHLu2H4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Гоша Дударь',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-08-27T14:28:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XXXJFIGQPx4rVR1YFoog-mZGCBg',
#    'id': {'kind': 'youtube#video', 'videoId': 'z7GgS7dR-4w'},
#    'snippet': {'publishedAt': '2021-08-17T10:49:24Z',
#     'channelId': 'UCLmizbxbiHdkDNa3138rTuw',
#     'title': 'API яндекс карт. Освой технологию карт уже сегодня! #Отхантера',
#     'description': 'Добрый день, Хантеры! В этом видео я расскажу о том, как начать работать с api яндекс карт Сначала нужно получить api.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z7GgS7dR-4w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z7GgS7dR-4w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z7GgS7dR-4w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ßлад Чиркоß - Сайты, Программирование, Photoshop',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-17T10:49:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3ADYJTwux39sDPf-dVuN9KrM-xk',
#    'id': {'kind': 'youtube#video', 'videoId': 'kK0w0dkyG3I'},
#    'snippet': {'publishedAt': '2016-04-23T17:16:08Z',
#     'channelId': 'UCIruFCNLXoKFEqboZhwrNfA',
#     'title': 'Yandex Disk REST API jQuery Plugin',
#     'description': 'В скринкасте представлен краткий обзор Yandex Disk REST API jQuery Plugin, который выполняет вставку и размещение ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kK0w0dkyG3I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kK0w0dkyG3I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kK0w0dkyG3I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Andrey Boldyrev',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-04-23T17:16:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W4oHwj0TzeFsY9fc43oY8n7SrSo',
#    'id': {'kind': 'youtube#video', 'videoId': 'yf9h4BEf5JY'},
#    'snippet': {'publishedAt': '2021-08-12T11:42:33Z',
#     'channelId': 'UCWojB8Beu6BF5-njHw5_xQQ',
#     'title': 'Пишем скрипт переводчик пользующийся yandex translate без api. PHP curl регулярки в прямом эфире.',
#     'description': 'Монтировать я ничего не хочу, так что сегодня будем писать скрипт-бот переводчик при помощи яндекса. За один присест ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yf9h4BEf5JY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yf9h4BEf5JY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yf9h4BEf5JY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Пишу ботов за еду в прямом эфире',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-12T11:42:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5ac1sgZ8YvZZbzSmXREd3PrDub8',
#    'id': {'kind': 'youtube#video', 'videoId': '9N22W4SaJX0'},
#    'snippet': {'publishedAt': '2013-01-25T06:01:51Z',
#     'channelId': 'UCFDJKkMqj8BXxXQXwIk8fag',
#     'title': 'api yandex map',
#     'description': 'обучающий ролик по быстрому добавлению карты в статью на сайте Движения.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9N22W4SaJX0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9N22W4SaJX0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9N22W4SaJX0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Александр Афанасьев',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-01-25T06:01:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OX2C1wgW6E0F6uDUCDhRx_20ErA',
#    'id': {'kind': 'youtube#video', 'videoId': 'yvuG0le7NkI'},
#    'snippet': {'publishedAt': '2022-08-02T04:00:34Z',
#     'channelId': 'UCEXs6f2wQ52ToYDIPzHyrSA',
#     'title': 'Yandex mapsga lokatsiya joylash | Manzilni yandexga kiritish',
#     'description': "Yandex maps ko'pchilik O'zbeksitonliklar foydalanadigan dasturlardan biri. Yandex Go orqali biror manzilga yetib borish uchun ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Abduganiyev Jakhongir',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T04:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZqqIKapagcSDnRwKpBwqVSkpso4',
#    'id': {'kind': 'youtube#video', 'videoId': '5aXNzigJ0c4'},
#    'snippet': {'publishedAt': '2022-01-10T13:46:50Z',
#     'channelId': 'UCWN_KT_CAjGZQG5grHldL8w',
#     'title': 'Сравнение систем распознавания голоса. Google vs Yandex vs Vosk vs Sphinx vs WebSpeech',
#     'description': 'Второй канал про программирование: https://youtube.com/@aidev Страница на гитхабе: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '𝙈𝙖𝙪𝙩𝙤𝙯 𝙏𝙚𝙘𝙝',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-10T13:46:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zPyjf7WQ80pgZ8XzjC9knUZyLLU',
#    'id': {'kind': 'youtube#video', 'videoId': 'MoX2F3AUlgI'},
#    'snippet': {'publishedAt': '2023-02-01T14:01:29Z',
#     'channelId': 'UCP5A5lVxaT7cO_LehpxjTZg',
#     'title': 'Yandex Hacked! Here&#39;s what we learned about Google...',
#     'description': "Did you hear about the Yandex data leak? In this video, you'll get a breakdown of everything there is to know about this leak.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MoX2F3AUlgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MoX2F3AUlgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MoX2F3AUlgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Matt Diggity',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-01T14:01:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fpcfXQ1hfpS0KK608e2EKfyVqUM',
#    'id': {'kind': 'youtube#video', 'videoId': 'DK3DZOppMbY'},
#    'snippet': {'publishedAt': '2010-08-26T07:15:52Z',
#     'channelId': 'UC-jDtdYvH4l20FYRUFDx4Aw',
#     'title': 'Сертификат Yandex.API',
#     'description': 'Сертификат Yandex.API.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DK3DZOppMbY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DK3DZOppMbY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DK3DZOppMbY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ilyatimoshin',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2010-08-26T07:15:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pJJbvdRKLc2sa_yUx1lOKSWsJ1k',
#    'id': {'kind': 'youtube#video', 'videoId': '2hasCzaXugw'},
#    'snippet': {'publishedAt': '2019-12-24T02:44:07Z',
#     'channelId': 'UCzwAJyw4MO4bAUMOs64X4cw',
#     'title': 'Logs API Яндекс Метрика  Что это?',
#     'description': 'Все мои видео по Logs API здесь: https://webkyrs.info/category/logs-api-iandeks-metrika.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2hasCzaXugw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2hasCzaXugw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2hasCzaXugw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Веб-программист. Дмитрий Ченгаев.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-12-24T02:44:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KMbrlDBn1nn3VfhaszrNzhHBNQU',
#    'id': {'kind': 'youtube#video', 'videoId': 'FCW-TWW2D7E'},
#    'snippet': {'publishedAt': '2021-09-18T13:30:05Z',
#     'channelId': 'UCSc0F-xAfKafnfqCW0YjW5A',
#     'title': 'Яндекс speechkit (yandex) онлайн озвучка бесплатно',
#     'description': 'Попробовать: https://cloud.yandex.ru/services/speechkit Предлагаю посмотреть видео о сервисе яндекс speechkit или же ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FCW-TWW2D7E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FCW-TWW2D7E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FCW-TWW2D7E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Деньги в интернете от Rozz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-18T13:30:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hgiwzYnMEzzfaMslB9o8Qr3j77M',
#    'id': {'kind': 'youtube#video', 'videoId': '3j9-ZWP6bb4'},
#    'snippet': {'publishedAt': '2021-03-07T09:59:51Z',
#     'channelId': 'UCO8H0dtOJzXD04Oqgq4nBog',
#     'title': 'Yandex cloud SpeechKit пример вызова асинхронного gRPC API на C#',
#     'description': 'Потоковый режим для распознавания коротких аудио Пример кода: https://github.com/MaxKhlupnov/Yandex.SpeechKit.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3j9-ZWP6bb4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3j9-ZWP6bb4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3j9-ZWP6bb4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Maxim Khlupnov',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-03-07T09:59:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J7p1t_aVap91KJiWrT4OezMgykQ',
#    'id': {'kind': 'youtube#video', 'videoId': '9TEgopG1dP8'},
#    'snippet': {'publishedAt': '2022-09-09T15:44:21Z',
#     'channelId': 'UCmG6NQyCc_IcOVtwauGWuCQ',
#     'title': 'Yandex translate bug',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '₺-1Lira',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-09T15:44:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '84leGl0CYKmAwOY2otG_Oj2nRKg',
#    'id': {'kind': 'youtube#video', 'videoId': 'a0jXjt9yiyw'},
#    'snippet': {'publishedAt': '2021-05-06T13:41:45Z',
#     'channelId': 'UCQ8bFlA4azoJQcf6QIvCWLA',
#     'title': '⚡️ React JS (O&#39;zbek) | Yandex Mapsdan foydalanamiz',
#     'description': "Bugungi React bo'yicha 17-darsimizda sizlar bilan React dasturimizda qanday qilib Yandex Mapsdan foydalanishni o'rganamiz.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a0jXjt9yiyw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/a0jXjt9yiyw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/a0jXjt9yiyw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Javohir Group',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-06T13:41:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wE_21gIfa9Fp5zyssnovWT7nFPY',
#    'id': {'kind': 'youtube#video', 'videoId': 'UXPsNO7v7tM'},
#    'snippet': {'publishedAt': '2020-06-04T18:25:40Z',
#     'channelId': 'UCvDQnTKnIAbQcabMhq2HlKA',
#     'title': 'Добавление адреса доставки по Yandex Api как на Wildberries ru',
#     'description': 'Разработка функционала добавления адресов для доставки товара клиентам интернет-магазина ВсеДляДеток как на ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UXPsNO7v7tM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UXPsNO7v7tM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UXPsNO7v7tM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Игорь К',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-06-04T18:25:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'momg7ysrnuU7fYL39SwAdU3OYHE',
#    'id': {'kind': 'youtube#video', 'videoId': 'skJVaaCEots'},
#    'snippet': {'publishedAt': '2016-12-26T11:29:01Z',
#     'channelId': 'UCWWfIyhjfJHdH1Kvx5p9gyg',
#     'title': 'API Яндекс.Метрики, API Яндекс.Вебмастер и XML.Yandex для построения отчетов - Семён Васильев',
#     'description': 'На примере нескольких кейсов продемонстрируем, как с помощью Python автоматизировать и значительно ускорить ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/skJVaaCEots/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/skJVaaCEots/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/skJVaaCEots/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Школа Вебмастеров',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-12-26T11:29:01Z'}}]}

# %% [markdown]
# **3. Добавьте в запрос параметр `order` (значение укажите параметра сами, любое из [документации](https://developers.google.com/youtube/v3/docs?hl=ru) по этому API).**

# %%
result = youtube.search().list(
    q='yandex api',
    part='id,snippet',
    maxResults=50,
    order='date'
).execute()
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'jbYTuNT38iOaGpJH_Ubc1YfC5Pg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'RU',
#  'pageInfo': {'totalResults': 957381, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'mUrE1tHYtptYO9NyML3IqjGmdv0',
#    'id': {'kind': 'youtube#video', 'videoId': '4rHvPy9vbM8'},
#    'snippet': {'publishedAt': '2023-03-17T16:11:24Z',
#     'channelId': 'UCcplM4yZKrfEeAifP7NBrAA',
#     'title': 'Yandex Translate, tutorial',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4rHvPy9vbM8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4rHvPy9vbM8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4rHvPy9vbM8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Technology news city',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-17T16:11:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GFf3UNW1Nvo8Wb0meKCpJez0dl0',
#    'id': {'kind': 'youtube#video', 'videoId': '-rCi_gpWYcs'},
#    'snippet': {'publishedAt': '2023-03-17T09:53:54Z',
#     'channelId': 'UCAZyYKTcwGBrAy3pfKZ0mug',
#     'title': 'Yandex Datalens. Дашборд за 15 минут. Анализируем продажи на Wildberries',
#     'description': 'В этом видео я рассказываю, как сделать дашборд для Анализа продаж на маркетплейсе Wildberries с помощью Яндекс ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-rCi_gpWYcs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-rCi_gpWYcs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-rCi_gpWYcs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': "Let's Play BI",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-17T09:53:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cni8yGzdYOjVSA5svFLTr-6xj_4',
#    'id': {'kind': 'youtube#video', 'videoId': 'F4PV_P5mTNA'},
#    'snippet': {'publishedAt': '2023-03-13T14:00:07Z',
#     'channelId': 'UC5aU-LX3mGFcDilEovn8lBw',
#     'title': 'Расширения Yii2: Урок 3. Yandex Map',
#     'description': 'В этом уроке разберем, как вставить карту Яндекса на сайт. В этом поможет расширение yii2-yandexmap. На карте можно ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F4PV_P5mTNA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F4PV_P5mTNA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F4PV_P5mTNA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DanilovCode - Уроки PHP',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-13T14:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GBKrkDTUfByXgyxm2rE1RpvlgUw',
#    'id': {'kind': 'youtube#video', 'videoId': 'OVFAjzGDU5w'},
#    'snippet': {'publishedAt': '2023-02-14T09:53:03Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Запускаем контейнерные приложения в Yandex Serverless Containers',
#     'description': 'Современные разработчики всё чаще выбирают контейнеры для решения своих задач. Так, они стали основным ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OVFAjzGDU5w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OVFAjzGDU5w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OVFAjzGDU5w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-14T09:53:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MVq-vmBTEgVQCxtukQOniCRP7yo',
#    'id': {'kind': 'youtube#video', 'videoId': 'szFUXInlifY'},
#    'snippet': {'publishedAt': '2023-02-06T12:51:41Z',
#     'channelId': 'UCkZ0aHtTjFy51Ur0DFcVRoQ',
#     'title': 'Оцифровка бизнеса на Wildberries на Yandex DataLens как на Power BI',
#     'description': 'Рассказываю как с использованием Yandex DataLens получать управленческие финансовые отчеты и дашборды по ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/szFUXInlifY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/szFUXInlifY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/szFUXInlifY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Оцифровка бизнеса, найдем точки роста прибыли Х2',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-06T12:51:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5wTMMNgeHFc8HDtdMw0nKTyh1ek',
#    'id': {'kind': 'youtube#video', 'videoId': 'iqiswbOGGPE'},
#    'snippet': {'publishedAt': '2023-01-05T02:09:31Z',
#     'channelId': 'UCJ5aX7dSC-MJ3dWOnLNbR5A',
#     'title': 'Alphabet Shuffle on Yandex Maps',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iqiswbOGGPE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iqiswbOGGPE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iqiswbOGGPE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ད\xa0IDK A GUN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-05T02:09:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Z6aYeBMURaVTqW82GEPTgVw7N4U',
#    'id': {'kind': 'youtube#video', 'videoId': 'ortdao18_QA'},
#    'snippet': {'publishedAt': '2022-11-23T00:34:49Z',
#     'channelId': 'UCcBTByRC4SdSHtOUY4QWxnQ',
#     'title': 'Bug Bounty #5 Reflected XSS (translate.yandex.com) $5000',
#     'description': 'When I use translation in Yandex, I also use the translation feature in Edge browser. And what happened after I translated it using ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ortdao18_QA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ortdao18_QA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ortdao18_QA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Syahri Ramadan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-23T00:34:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6rzY_Fz3hju6YmiqJxNZKFC7pPg',
#    'id': {'kind': 'youtube#video', 'videoId': 'XWa_0sG-e9Q'},
#    'snippet': {'publishedAt': '2022-11-20T11:03:01Z',
#     'channelId': 'UClidydU89-1rOzkyPMhB0hQ',
#     'title': 'Изучаем API сервиса Яндекс.Погода',
#     'description': 'Рассказано и показано как читать API и подключать сервис Яндекс.Погода к конструктору чат-ботов LeadTeh. ✳️ Создай ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XWa_0sG-e9Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Чат-боты от Владимира',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-20T11:03:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hAKjA-2ukUsHjw657bQrghiE754',
#    'id': {'kind': 'youtube#video', 'videoId': 'ObycYqL3Sfs'},
#    'snippet': {'publishedAt': '2022-11-15T09:56:25Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Храним и обрабатываем логи с Yandex Cloud Logging',
#     'description': 'На вебинаре мы рассмотрели, какие сервисы Yandex Cloud плотно интегрированы с Yandex Cloud Logging. Показали, как ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ObycYqL3Sfs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ObycYqL3Sfs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ObycYqL3Sfs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-15T09:56:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BCD9IzBiIO1iGGHBnzR-ppG9rZQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'wujc11poWc0'},
#    'snippet': {'publishedAt': '2022-11-07T09:33:15Z',
#     'channelId': 'UCtGpsB13JqWqHw41a9ssdpQ',
#     'title': 'How To Download Yandex.Weather',
#     'description': 'shorts How To Download Yandex.Weather Please like and subscribe to my channel and press the bell icon to get new video ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wujc11poWc0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wujc11poWc0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wujc11poWc0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Tech Warmer',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-07T09:33:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i00aJiahNr9IsQy1gkPwxYZl_O8',
#    'id': {'kind': 'youtube#video', 'videoId': 'QkNaBL4ky4U'},
#    'snippet': {'publishedAt': '2022-10-25T10:02:33Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Разработка пользовательских интеграций для API Gateway',
#     'description': 'На этом вебинаре мы рассказали, как сделать пользовательскую интеграцию сервиса API Gateway с базой данных YDB в ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QkNaBL4ky4U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-25T10:02:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm9rGHXxTiWwfWtL5-xfxCS2a3zk',
#    'id': {'kind': 'youtube#video', 'videoId': 'QLnalD5volM'},
#    'snippet': {'publishedAt': '2022-10-23T13:00:26Z',
#     'channelId': 'UCtiDQJVTuGiIAXduxR6EKIQ',
#     'title': 'Yandex Maps',
#     'description': 'Yandex_mapkit - плагин для отображения карт Яндекса на iOS и Android. https://pub.dev/packages/yandex_mapkit ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QLnalD5volM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QLnalD5volM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QLnalD5volM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ART PROGRAMS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-23T13:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nf7iTdxRbW1RfgTsYkWOlyIYtuE',
#    'id': {'kind': 'youtube#video', 'videoId': 'cfOPEHgg9cQ'},
#    'snippet': {'publishedAt': '2022-10-18T19:46:27Z',
#     'channelId': 'UC4H30ysoFC1DpKQYXEUXVTg',
#     'title': 'How to use Yandex translate Apple | Yandex translate App se kaise koi b language change Karen |#tech',
#     'description': 'Welcome to the "Tech with naina" your own YouTube channel. We created this channel for android apps, we upload daily videos ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cfOPEHgg9cQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cfOPEHgg9cQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cfOPEHgg9cQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Tech with Naina',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-18T19:46:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J7p1t_aVap91KJiWrT4OezMgykQ',
#    'id': {'kind': 'youtube#video', 'videoId': '9TEgopG1dP8'},
#    'snippet': {'publishedAt': '2022-09-09T15:44:21Z',
#     'channelId': 'UCmG6NQyCc_IcOVtwauGWuCQ',
#     'title': 'Yandex translate bug',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9TEgopG1dP8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '₺-1Lira',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-09T15:44:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VGjjEYd1pYDoTUpTsPRvZ31o6QY',
#    'id': {'kind': 'youtube#video', 'videoId': '4vttt5eAqko'},
#    'snippet': {'publishedAt': '2022-09-05T14:00:11Z',
#     'channelId': 'UCekiUWTObDKZnaeS-reYQbg',
#     'title': 'Traductor Yandex en AppInventor',
#     'description': 'Canal de ProgramadorNovato: https://www.youtube.com/c/programadornovato Facebook: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4vttt5eAqko/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4vttt5eAqko/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4vttt5eAqko/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Programador Novato',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-05T14:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dtK0dFW9WeJuLHmSPsdCMxrue-U',
#    'id': {'kind': 'youtube#video', 'videoId': 'QLk5j6KtmH4'},
#    'snippet': {'publishedAt': '2022-08-05T17:40:34Z',
#     'channelId': 'UCkSTrBfwUiVe6PlgiO0kolA',
#     'title': 'An Alternative To Yandex Translate: Use DocTranslator!',
#     'description': 'doctranslator #yandex #translationservices Find Yandex Translate alternative here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QLk5j6KtmH4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QLk5j6KtmH4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QLk5j6KtmH4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Translation Services USA',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-05T17:40:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MVd9KyQPVpH8Qa0JnOMrLGdQADs',
#    'id': {'kind': 'youtube#video', 'videoId': 'fhGz-qpY_Fo'},
#    'snippet': {'publishedAt': '2022-08-02T11:55:40Z',
#     'channelId': 'UC0e-6fkzjQB5Kdr-yMwdwlg',
#     'title': 'Best tool to Translate Image online | Yandex Translate vs ImageTranslate',
#     'description': 'Yandex Translate is among the best machine translation tools available on the internet. Yandex Translate also offers features to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fhGz-qpY_Fo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fhGz-qpY_Fo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fhGz-qpY_Fo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ImageTranslate',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T11:55:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FPjLgdKll1OZa_4sB3LMVA0DHKw',
#    'id': {'kind': 'youtube#video', 'videoId': 'ipsGqf4pFbw'},
#    'snippet': {'publishedAt': '2022-08-02T04:58:57Z',
#     'channelId': 'UC9wLYI6holb1oAt1cc7zmBQ',
#     'title': '5 Yandex menerjemahkan fitur yang mampu kompetitif google translate',
#     'description': 'Yndex Translator, yang merupakan layanan yang diprakarsai oleh YNDEX untuk menerjemahkan teks, situs web, dan foto #5Fitur ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ipsGqf4pFbw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ipsGqf4pFbw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ipsGqf4pFbw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Berita Hari Ini Indonesia',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T04:58:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OX2C1wgW6E0F6uDUCDhRx_20ErA',
#    'id': {'kind': 'youtube#video', 'videoId': 'yvuG0le7NkI'},
#    'snippet': {'publishedAt': '2022-08-02T04:00:34Z',
#     'channelId': 'UCEXs6f2wQ52ToYDIPzHyrSA',
#     'title': 'Yandex mapsga lokatsiya joylash | Manzilni yandexga kiritish',
#     'description': "Yandex maps ko'pchilik O'zbeksitonliklar foydalanadigan dasturlardan biri. Yandex Go orqali biror manzilga yetib borish uchun ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yvuG0le7NkI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Abduganiyev Jakhongir',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-02T04:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6htsLsuUQ4oT4ENpeyUmVt-CleU',
#    'id': {'kind': 'youtube#video', 'videoId': 'uFGNUIOTbJU'},
#    'snippet': {'publishedAt': '2022-07-27T10:50:47Z',
#     'channelId': 'UC6Dqw4PO-1moBs7xh4Zp8gQ',
#     'title': 'Строим маршруты к объектам NextGIS Web с помощью Yandex.Maps',
#     'description': 'Пример интеграции веб-карт NextGIS Web и мобильного приложения Яндекс.Карты. С помощью специально ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uFGNUIOTbJU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uFGNUIOTbJU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uFGNUIOTbJU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'NextGIS по-русски',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-27T10:50:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kS86ySKgV9jBPnNkLSjNFHWKyHc',
#    'id': {'kind': 'youtube#video', 'videoId': 'xhs52A49hZw'},
#    'snippet': {'publishedAt': '2022-07-22T12:49:41Z',
#     'channelId': 'UCYSI7rl6Ll3yeRUW8cEUQXw',
#     'title': 'Business Data Scraper | Google Maps and Yandex Maps | Not Selenium!',
#     'description': 'for sale contact: https://t.me/keyiflerolsun.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xhs52A49hZw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xhs52A49hZw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xhs52A49hZw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kekik Akademi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-22T12:49:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eForhij4Rhsw20zmmwdz08NgVvQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'nCW-esaFB9s'},
#    'snippet': {'publishedAt': '2022-07-14T11:00:13Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'TradingView Alerts WebHook + Python = Telegram | with Yandex Cloud Functions and Telegram Bot API',
#     'description': 'В TradingView есть классная штука кот называется Alerts. Алерты особенно классны тем что умеют отправлять WebHook, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nCW-esaFB9s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-14T11:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zjeScyo2xlccmMsGNaG8xfb7djg',
#    'id': {'kind': 'youtube#video', 'videoId': 'gJf9rMvH1Bg'},
#    'snippet': {'publishedAt': '2022-07-14T10:01:25Z',
#     'channelId': 'UC6E9ANtZQr9NI_FSp7x3NCw',
#     'title': 'Yandex Webmaster Api Key Generator || Instant Indexing Api  || AutoFast Wordpress Indexing Plugin',
#     'description': 'Yandex Webmaster Api Key Generator || Instant Indexing Api || AutoFast Wordpress Indexing Plugin .',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gJf9rMvH1Bg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gJf9rMvH1Bg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gJf9rMvH1Bg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Wopensys Official',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-14T10:01:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fYfo0VgabkqH4Q7pZqIrwwlD-YM',
#    'id': {'kind': 'youtube#video', 'videoId': 'uBJyVLNxpFo'},
#    'snippet': {'publishedAt': '2022-07-13T18:12:15Z',
#     'channelId': 'UC4xKQ5qoW9RXWXIzaQer-OQ',
#     'title': 'Поиски озера Белое. Ужасы.  https://yandex.ru/maps/-/CCUNZKAEgC',
#     'description': 'Полно в Вятском крае озер с названием "Чёрное" (штук 5 точно). Давно наладился найти озеро "Белое" (С таким ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uBJyVLNxpFo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uBJyVLNxpFo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uBJyVLNxpFo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Vladimir Gluhov',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-13T18:12:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uNg63Hyz2bxNREG1NHg1udXFgjE',
#    'id': {'kind': 'youtube#video', 'videoId': '1AmSMUOpsWY'},
#    'snippet': {'publishedAt': '2022-05-17T12:06:54Z',
#     'channelId': 'UCyhGFKKvCXwUnU7FSjsMvsQ',
#     'title': 'cara buka video dewasa yandex',
#     'description': 'cara buka video dewasa yandex,,cara buka video dewasa yandex account,,cara buka video dewasa yandex api,,cara buka video ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1AmSMUOpsWY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1AmSMUOpsWY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1AmSMUOpsWY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'tiren olahraga',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-17T12:06:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FreGZLGoR8osUYdsc_jFtDQayCc',
#    'id': {'kind': 'youtube#video', 'videoId': '7nw_Knajj6I'},
#    'snippet': {'publishedAt': '2022-05-17T09:37:19Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Большой облачный митап Yandex Cloud в Казахстане',
#     'description': 'Большой облачный митап Yandex Cloud прошел на площадке Astana IT University. Шесть сессий с участием специалистов ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7nw_Knajj6I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7nw_Knajj6I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7nw_Knajj6I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-17T09:37:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TORBqRv0y2sFzJGtqRJQDuirJBs',
#    'id': {'kind': 'youtube#video', 'videoId': 'R0PCo93gDlA'},
#    'snippet': {'publishedAt': '2022-04-25T10:13:28Z',
#     'channelId': 'UCjWOzgG0oTFHy4N4BeDmBhg',
#     'title': 'Как перенести 1С в Yandex Cloud',
#     'description': 'Пошаговая инструкция переноса 1С из изолированной облачной среды в Yandex.Cloud на примере сценария миграции 1С ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R0PCo93gDlA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R0PCo93gDlA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/R0PCo93gDlA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yandex Cloud',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-25T10:13:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OeIIdQuCohr-ZeewGadyerfuz2o',
#    'id': {'kind': 'youtube#video', 'videoId': '5lgHCuCuI5s'},
#    'snippet': {'publishedAt': '2022-04-24T13:16:11Z',
#     'channelId': 'UCrYD2NXH5n3BeOBhFIlsMBQ',
#     'title': 'Способ применения системы Yandex vision на производстве.',
#     'description': 'Способ применения системы Yandex vision на производстве для распознавания номеров и учета циклов оснастки.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5lgHCuCuI5s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5lgHCuCuI5s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5lgHCuCuI5s/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Сергей Андриянов',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-24T13:16:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm_a3dsclH4PNYpUQ4qrapCfv4Rw',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZvNS81aOQe0'},
#    'snippet': {'publishedAt': '2022-03-30T15:00:18Z',
#     'channelId': 'UCSL8Rocs9KefbE_0vTc9KDQ',
#     'title': 'How to index Websites Faster with API | Bing Yandex and google API | site indexing news',
#     'description': 'How to index Websites Faster with API | Bing Yandex and google API | site indexing news seo for beginners, search engine ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZvNS81aOQe0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZvNS81aOQe0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZvNS81aOQe0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Muddaser Altaf - Helping Orange',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-30T15:00:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Yj7xdRQXygSzbQ0xLXonu2d43RQ',
#    'id': {'kind': 'youtube#video', 'videoId': '_xCh8LHEJJA'},
#    'snippet': {'publishedAt': '2022-03-26T04:58:14Z',
#     'channelId': 'UCzwAJyw4MO4bAUMOs64X4cw',
#     'title': 'Как получить токен API Яндекс Метрики',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_xCh8LHEJJA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Веб-программист. Дмитрий Ченгаев.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-26T04:58:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Wigu7XLAKb03HxNqZFhzK5cVLMc',
#    'id': {'kind': 'youtube#video', 'videoId': 'ewIiOoJ_I-8'},
#    'snippet': {'publishedAt': '2022-03-13T14:34:14Z',
#     'channelId': 'UCcIWLHY_EfPwtX48Y2hNhSw',
#     'title': 'Peta Palestina Versi Google maps &amp; Yandex Maps ‼️#Shorts  #palestine #rusia #america',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ewIiOoJ_I-8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ewIiOoJ_I-8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ewIiOoJ_I-8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OZIL HATUALA',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-13T14:34:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'w-xcJRpdLGzbVc6Zj_SiEd4op9c',
#    'id': {'kind': 'youtube#video', 'videoId': 'XfkD0ihZk8I'},
#    'snippet': {'publishedAt': '2022-03-13T14:19:06Z',
#     'channelId': 'UC1FY20PVRX6RS91ymHYCH1g',
#     'title': 'Интеграция Yandex Forms и Google Sheets | Как передавать данные из Яндекс Форм в гугл-таблицы',
#     'description': 'Соединяйте нужные сервисы за 5 минут без программистов. 14 дней бесплатно: https://clck.ru/dhDLK В данном примере мы ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XfkD0ihZk8I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XfkD0ihZk8I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XfkD0ihZk8I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Albato',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-13T14:19:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i3alipvXPK_mmKC6XF3QLNJm2ag',
#    'id': {'kind': 'youtube#video', 'videoId': 'ArBCxIZaNMs'},
#    'snippet': {'publishedAt': '2022-03-05T11:14:19Z',
#     'channelId': 'UCMS0vxI1a-TVNZJEZmiJX9A',
#     'title': 'Yandex maps car spotted on google earth &amp; google maps | Trung Dinh #subscribe',
#     'description': 'Yandex maps car spotted on google earth & google maps | Trung Dinh #subscribe Music: BigCarTheft Musician: Jason Shaw ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ArBCxIZaNMs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ArBCxIZaNMs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ArBCxIZaNMs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Trung Dinh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-05T11:14:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uOM1ebzqC7ZGshtzsUsVQDaJ1yw',
#    'id': {'kind': 'youtube#video', 'videoId': 'AYIqm4nWB1Y'},
#    'snippet': {'publishedAt': '2022-03-01T15:22:10Z',
#     'channelId': 'UCm3GLiJRtmTR2pfyR2GYuYA',
#     'title': 'FBS Яндекс.Маркет автоматизация 1С: УТ 11 по API',
#     'description': 'Это вводное видео, в котором я рассказываю о базовом функционале нашего модуля и его отличиях от стандартного ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AYIqm4nWB1Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Бюро полезных разработок',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-01T15:22:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qkfezLotDTaeTloUh5Xg0XeLGjU',
#    'id': {'kind': 'youtube#video', 'videoId': 'U5Dhp6vWyx4'},
#    'snippet': {'publishedAt': '2022-03-01T14:50:19Z',
#     'channelId': 'UCq3bVEw7exNtfuyZ78HHoNQ',
#     'title': 'Instantly Index Content To Search Engines | Google, Bing, and Yandex [2022]',
#     'description': 'Have a blog or website? You publish content daily but your content not Indexing fast. So you want to Index articles instantly? If yes ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U5Dhp6vWyx4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Pronay Sarkar',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-01T14:50:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Wt6G9zfebk5MBhilarEwz2KNO1g',
#    'id': {'kind': 'youtube#video', 'videoId': 'SYwIFlXg-3w'},
#    'snippet': {'publishedAt': '2022-02-26T08:53:32Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Yandex Cloud Functions 👍 Что это и как использовать? (FaaS, Python)',
#     'description': 'Как ЛЕГКО и БЕСПЛАТНО захостить свой код на Python без знания nginx, gunicorn, django и т.д. ✔️ Как получить HTTPS ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SYwIFlXg-3w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-26T08:53:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jIBWetS6sF-BpEv_32lWQT5JD8Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'DrmoHfeMn5E'},
#    'snippet': {'publishedAt': '2022-01-28T00:27:30Z',
#     'channelId': 'UCoB3e5kGFu5mK2hCKyz0LqA',
#     'title': 'Discord Translator Bot using Yandex Translate API tool',
#     'description': "Using Yandex Translate's API, I created a Discord bot that would read the text in text channels and translate it to the English ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DrmoHfeMn5E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DrmoHfeMn5E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DrmoHfeMn5E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Adam Densman',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-28T00:27:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZqqIKapagcSDnRwKpBwqVSkpso4',
#    'id': {'kind': 'youtube#video', 'videoId': '5aXNzigJ0c4'},
#    'snippet': {'publishedAt': '2022-01-10T13:46:50Z',
#     'channelId': 'UCWN_KT_CAjGZQG5grHldL8w',
#     'title': 'Сравнение систем распознавания голоса. Google vs Yandex vs Vosk vs Sphinx vs WebSpeech',
#     'description': 'Второй канал про программирование: https://youtube.com/@aidev Страница на гитхабе: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5aXNzigJ0c4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '𝙈𝙖𝙪𝙩𝙤𝙯 𝙏𝙚𝙘𝙝',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-10T13:46:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4xPuTzuiGM1S4q17dKTjqySj-2E',
#    'id': {'kind': 'youtube#video', 'videoId': '5x6WDB2NvFU'},
#    'snippet': {'publishedAt': '2021-12-27T03:05:43Z',
#     'channelId': 'UCPF-oYb2-xN5FbCXy0167Gg',
#     'title': 'GIS: OpenLayers 3: projection for Yandex.Maps',
#     'description': 'GIS: OpenLayers 3: projection for Yandex.Maps Helpful? Please support me on Patreon: https://www.patreon.com/roelvandepaar ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5x6WDB2NvFU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5x6WDB2NvFU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5x6WDB2NvFU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Roel Van de Paar',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-27T03:05:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GTd6jdusBAEGVyGoz6i8Wkl9dM0',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZHDhlbG3wXo'},
#    'snippet': {'publishedAt': '2021-12-25T20:11:40Z',
#     'channelId': 'UCOhtB5yH32j3tCU8aVp2diQ',
#     'title': 'Parte 1/2 App Inventor: Traductor textos. Pantalla principal. Yandex Translate',
#     'description': 'En este vídeo podéis ver un traductor de textos, de forma que pase del español al inglés o al aleman. He adaptado este vídeo de ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZHDhlbG3wXo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZHDhlbG3wXo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZHDhlbG3wXo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ángel Mota Salido',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-25T20:11:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KxxssygjyqD5pm4YXTMaIlioNlA',
#    'id': {'kind': 'youtube#video', 'videoId': 'mxIiqD43zDQ'},
#    'snippet': {'publishedAt': '2021-12-05T17:14:23Z',
#     'channelId': 'UCkj2qehrV9yqAb6ebGzy7mw',
#     'title': 'Yandex Translate is weird...',
#     'description': 'Yandex Translate is weird.. ---- Thanks for watching! Yandex Translate: https://translate.yandex.com/ #justk #shorts ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mxIiqD43zDQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mxIiqD43zDQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mxIiqD43zDQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'justk',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-05T17:14:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nywv-Z_GrKrN7QWWtyBPTfBnHFc',
#    'id': {'kind': 'youtube#video', 'videoId': 'g3NF-T-2soI'},
#    'snippet': {'publishedAt': '2021-11-30T19:00:11Z',
#     'channelId': 'UCWx4gcpschg_bE0lF3xDD4Q',
#     'title': 'I broke Yandex Translate',
#     'description': 'breath pause* today i basically destroy the tts of yandex translate by bombing it full of stange characters that nobody uses. Enjoy.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g3NF-T-2soI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g3NF-T-2soI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g3NF-T-2soI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Freshykz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-30T19:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5ZXYEK0rotpnz8NjvyRBRlF3hX0',
#    'id': {'kind': 'youtube#video', 'videoId': 'BgRmjnsMKtY'},
#    'snippet': {'publishedAt': '2021-11-28T06:30:38Z',
#     'channelId': 'UCPF-oYb2-xN5FbCXy0167Gg',
#     'title': 'GIS: How to export polyline layer from Yandex Maps?',
#     'description': 'GIS: How to export polyline layer from Yandex Maps? Helpful? Please support me on Patreon: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BgRmjnsMKtY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BgRmjnsMKtY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BgRmjnsMKtY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Roel Van de Paar',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-28T06:30:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'NmNMMJLifrNK_CSUuHSoHFw5kgg',
#    'id': {'kind': 'youtube#video', 'videoId': 'NjhuzFXd0wM'},
#    'snippet': {'publishedAt': '2021-11-20T17:35:34Z',
#     'channelId': 'UCIzPljSi9SJXyagkgwdWCbw',
#     'title': 'Let&#39;s trying yandex translate this!',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NjhuzFXd0wM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NjhuzFXd0wM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NjhuzFXd0wM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Fanboy?',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-20T17:35:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MZ2c_S86zDaEVRSleIdpOhxb75s',
#    'id': {'kind': 'youtube#video', 'videoId': 'sY93xDZQ4YE'},
#    'snippet': {'publishedAt': '2021-11-20T09:35:17Z',
#     'channelId': 'UCQAYt0FQ42868VuI9ck7OZA',
#     'title': 'Google / Yandex Translate Rap - RICH DASHA (by White Eagle)',
#     'description': 'Thanks for Watching (Musical Genre),google translate,google translate easter eggs,google translate tutorials,beatbox tutorial ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sY93xDZQ4YE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sY93xDZQ4YE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sY93xDZQ4YE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'White Eagle',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-20T09:35:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pxoffrUW5Cqgk_gx6X8c6jWUA34',
#    'id': {'kind': 'youtube#video', 'videoId': 'oT9oAyx2X-o'},
#    'snippet': {'publishedAt': '2021-11-18T21:00:31Z',
#     'channelId': 'UC1I051LTYFTcySKAmkafnhw',
#     'title': 'Instantly Translate Images of Text for English Learners with Yandex Translate',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oT9oAyx2X-o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oT9oAyx2X-o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oT9oAyx2X-o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Tech Coach Juarez',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-18T21:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6GtU92vEd_0M_eW9Q2KQ0qVUSFo',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ep2pJo2_DJc'},
#    'snippet': {'publishedAt': '2021-11-18T17:22:57Z',
#     'channelId': 'UCzz1ofQIE6VJm73BSOkgxUw',
#     'title': 'Use IndexNow Protocol to index your webpages to Bing and Yandex search engines',
#     'description': 'IndexNow protocol is recently developed by Bing and Yandex to quickly index webpages which are recently published or updated ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ep2pJo2_DJc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ep2pJo2_DJc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ep2pJo2_DJc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Switch2Knowledge',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-18T17:22:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lYguWixqqJTnPnbFEtDfPcXihUw',
#    'id': {'kind': 'youtube#video', 'videoId': 'w7Sx_QNCekE'},
#    'snippet': {'publishedAt': '2021-11-18T13:15:17Z',
#     'channelId': 'UCf6kozNejHoQuFhBDB8cfxA',
#     'title': 'Python + Flask + Docker + Nginx + PostgreSQL + Git + Yandex Cloud. Разворачиваю веб приложение.',
#     'description': 'Пример веб приложения на Python и Flask, кот. использует базу данных PostreSQL и веб админку к ней - pgAdmin, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w7Sx_QNCekE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w7Sx_QNCekE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w7Sx_QNCekE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Azzrael Code',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-18T13:15:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WnnBws8a82A1IYjW5MHocxsMMEg',
#    'id': {'kind': 'youtube#video', 'videoId': '2Lq_Z1NShk0'},
#    'snippet': {'publishedAt': '2021-11-18T08:47:21Z',
#     'channelId': 'UCGg79m3j9bEXNpWVcO-_I3Q',
#     'title': 'API YANDEX.UBER',
#     'description': 'Как получить API ключ для ваших диспетчерских Yandex и UBER.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2Lq_Z1NShk0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2Lq_Z1NShk0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2Lq_Z1NShk0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'taxiCRM. Настройка.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-18T08:47:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2m6FcPitkPVGhbMdpdsURQW0RBI',
#    'id': {'kind': 'youtube#video', 'videoId': 'YFrHg_dJr2E'},
#    'snippet': {'publishedAt': '2021-11-17T15:07:17Z',
#     'channelId': 'UCBUz9j-UjiVdkxHoQL4pRBA',
#     'title': 'Yandex &amp; Qwant Maps - Overview',
#     'description': 'How good are thise alternative map apps Yandex & Qwant. What are their strength and weaknesses. Are you using any of them?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YFrHg_dJr2E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YFrHg_dJr2E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YFrHg_dJr2E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Techview Podcast',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-17T15:07:17Z'}}]}

# %% [markdown]
# **4. Создайте таблицу по всем видео, которые были выгружены на данный момент.**

# %%
import pandas as pd

# %%
dfp = []
for el in result['items']:
        video_id = el['id']['videoId']
        title = el['snippet']['title']
        description = el['snippet']['description']
        published_at = el['snippet']['publishedAt']
        dfp.append({'video_id': video_id, 'title': title, 'description': description, 'published_at': published_at})
dfpd = pd.DataFrame(dfp)
dfpd.head()
# Out:
#       video_id                                              title  \
# 0  4rHvPy9vbM8                         Yandex Translate, tutorial
# 1  -rCi_gpWYcs  Yandex Datalens. Дашборд за 15 минут. Анализир...
# 2  F4PV_P5mTNA                Расширения Yii2: Урок 3. Yandex Map
# 3  OVFAjzGDU5w  Запускаем контейнерные приложения в Yandex Ser...
# 4  szFUXInlifY  Оцифровка бизнеса на Wildberries на Yandex Dat...
#
#                                          description          published_at
# 0                                                     2023-03-17T16:11:24Z
# 1  В этом видео я рассказываю, как сделать дашбор...  2023-03-17T09:53:54Z
# 2  В этом уроке разберем, как вставить карту Янде...  2023-03-13T14:00:07Z
# 3  Современные разработчики всё чаще выбирают кон...  2023-02-14T09:53:03Z
# 4  Рассказываю как с использованием Yandex DataLe...  2023-02-06T12:51:41Z

# %% [markdown]
# **5. Обратите внимание на `nextPageToken`. Запустите цикл, который будет работать, *пока* `nextPageToken` есть в выдаче и количество его итераций не превысило десять.**
#
# *Ограничение в десять итераций наше собственное, чтобы вы на первых порах не превысили лимит по квоте.*
#
# *Будьте внимательны с циклом! Если, не подумав, запустите бесконечный цикл, то квота закончится за раз и придется ждать следующий день.*
#
# **На каждой итерации цикла должно происходить:**
# + создание нового запроса (пусть в него добавляется аругумент `pageToken`, также почитайте о нем в документации)
# + создание новой таблицы (очевидно, из новых, полученных пунктом выше, данных)
# + объединение новой таблицы и той, что была до нее (здесь обратите внимание на [документацию](https://pandas.pydata.org/docs/user_guide/merging.html) модуля pandas и работу метода `.concat()`)
#
# **Посмотрите на количество видео в ваших данных, а затем [уберите из таблицы дубликаты](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html?highlight=drop_duplicates#pandas.DataFrame.drop_duplicates) по столбцу `id.videoId`.**

# %%
dfp = []
nextPageToken = None
for i in range(10):
    result = youtube.search().list(
        q='yandex api',
        part='id,snippet',
        maxResults=50,
        order='date',
        pageToken=nextPageToken
    ).execute()
    nextPageToken = result.get('nextPageToken')
    for el in result['items']:
        video_id = el['id'].get('videoId')
        title = el['snippet']['title']
        description = el['snippet']['description']
        published_at = el['snippet']['publishedAt']
        dfp.append({'video_id': video_id, 'title': title, 'description': description, 'published_at': published_at})
    new_df = pd.DataFrame(dfp)
    if i == 0:
        combined_df = new_df
    else:
        combined_df = pd.concat([combined_df, new_df])
    if not nextPageToken:
        break
combined_df.drop_duplicates(subset=['video_id'], inplace=True)

# %%
combined_df.dropna(inplace=True)

# %%
combined_df.head()
# Out:
#       video_id                                              title  \
# 0  4rHvPy9vbM8                         Yandex Translate, tutorial
# 1  -rCi_gpWYcs  Yandex Datalens. Дашборд за 15 минут. Анализир...
# 2  F4PV_P5mTNA                Расширения Yii2: Урок 3. Yandex Map
# 3  OVFAjzGDU5w  Запускаем контейнерные приложения в Yandex Ser...
# 4  szFUXInlifY  Оцифровка бизнеса на Wildberries на Yandex Dat...
#
#                                          description          published_at
# 0                                                     2023-03-17T16:11:24Z
# 1  В этом видео я рассказываю, как сделать дашбор...  2023-03-17T09:53:54Z
# 2  В этом уроке разберем, как вставить карту Янде...  2023-03-13T14:00:07Z
# 3  Современные разработчики всё чаще выбирают кон...  2023-02-14T09:53:03Z
# 4  Рассказываю как с использованием Yandex DataLe...  2023-02-06T12:51:41Z

# %% [markdown]
# **6. Для всех видео соберите статистику (количество промотров, лайков, комментариев), используйте метод `.videos()`. Добавьте эти данные в вашу таблицу.**

# %%
dfp_st = []
for idv in combined_df['video_id']:
    response = youtube.videos().list(
        id = idv,
        part = 'statistics'
    ).execute()
    stats = response['items'][0]['statistics']
    view_count = int(stats['viewCount'])
    if 'likeCount' in stats:
        like_count = int(stats['likeCount'])
    else:
        like_count = 0
    if 'commentCount' in stats:
        comment_count = int(stats['commentCount'])
    else:
        comment_count = 0
    dfp_st.append({'video_id': idv, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count})
dfp_st
# Out:
# [{'video_id': '4rHvPy9vbM8',
#   'view_count': 125,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': '-rCi_gpWYcs',
#   'view_count': 186,
#   'like_count': 3,
#   'comment_count': 2},
#  {'video_id': 'F4PV_P5mTNA',
#   'view_count': 121,
#   'like_count': 4,
#   'comment_count': 1},
#  {'video_id': 'OVFAjzGDU5w',
#   'view_count': 1716,
#   'like_count': 67,
#   'comment_count': 2},
#  {'video_id': 'szFUXInlifY',
#   'view_count': 463,
#   'like_count': 12,
#   'comment_count': 8},
#  {'video_id': 'iqiswbOGGPE',
#   'view_count': 157,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'ortdao18_QA',
#   'view_count': 401,
#   'like_count': 13,
#   'comment_count': 2},
#  {'video_id': 'XWa_0sG-e9Q',
#   'view_count': 989,
#   'like_count': 16,
#   'comment_count': 2},
#  {'video_id': 'ObycYqL3Sfs',
#   'view_count': 1028,
#   'like_count': 28,
#   'comment_count': 2},
#  {'video_id': 'wujc11poWc0',
#   'view_count': 220,
#   'like_count': 7,
#   'comment_count': 0},
#  {'video_id': 'QkNaBL4ky4U',
#   'view_count': 1635,
#   'like_count': 35,
#   'comment_count': 2},
#  {'video_id': 'QLnalD5volM',
#   'view_count': 268,
#   'like_count': 6,
#   'comment_count': 2},
#  {'video_id': 'cfOPEHgg9cQ',
#   'view_count': 8,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': '9TEgopG1dP8',
#   'view_count': 173,
#   'like_count': 5,
#   'comment_count': 3},
#  {'video_id': '4vttt5eAqko',
#   'view_count': 1214,
#   'like_count': 19,
#   'comment_count': 2},
#  {'video_id': 'QLk5j6KtmH4',
#   'view_count': 223,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'fhGz-qpY_Fo',
#   'view_count': 546,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': 'ipsGqf4pFbw',
#   'view_count': 24,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'yvuG0le7NkI',
#   'view_count': 3980,
#   'like_count': 259,
#   'comment_count': 33},
#  {'video_id': 'uFGNUIOTbJU',
#   'view_count': 153,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': 'xhs52A49hZw',
#   'view_count': 364,
#   'like_count': 3,
#   'comment_count': 1},
#  {'video_id': 'nCW-esaFB9s',
#   'view_count': 4003,
#   'like_count': 167,
#   'comment_count': 42},
#  {'video_id': 'gJf9rMvH1Bg',
#   'view_count': 234,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': 'uBJyVLNxpFo',
#   'view_count': 60,
#   'like_count': 1,
#   'comment_count': 3},
#  {'video_id': '1AmSMUOpsWY',
#   'view_count': 6918,
#   'like_count': 19,
#   'comment_count': 8},
#  {'video_id': '7nw_Knajj6I',
#   'view_count': 669,
#   'like_count': 8,
#   'comment_count': 2},
#  {'video_id': 'R0PCo93gDlA',
#   'view_count': 1164,
#   'like_count': 36,
#   'comment_count': 5},
#  {'video_id': '5lgHCuCuI5s',
#   'view_count': 125,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'ZvNS81aOQe0',
#   'view_count': 394,
#   'like_count': 7,
#   'comment_count': 2},
#  {'video_id': '_xCh8LHEJJA',
#   'view_count': 2436,
#   'like_count': 33,
#   'comment_count': 3},
#  {'video_id': 'ewIiOoJ_I-8',
#   'view_count': 383,
#   'like_count': 7,
#   'comment_count': 1},
#  {'video_id': 'XfkD0ihZk8I',
#   'view_count': 2427,
#   'like_count': 22,
#   'comment_count': 9},
#  {'video_id': 'ArBCxIZaNMs',
#   'view_count': 938,
#   'like_count': 0,
#   'comment_count': 2},
#  {'video_id': 'AYIqm4nWB1Y',
#   'view_count': 781,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': 'U5Dhp6vWyx4',
#   'view_count': 7535,
#   'like_count': 111,
#   'comment_count': 11},
#  {'video_id': 'SYwIFlXg-3w',
#   'view_count': 7188,
#   'like_count': 188,
#   'comment_count': 23},
#  {'video_id': 'DrmoHfeMn5E',
#   'view_count': 312,
#   'like_count': 3,
#   'comment_count': 3},
#  {'video_id': '5aXNzigJ0c4',
#   'view_count': 1618,
#   'like_count': 72,
#   'comment_count': 12},
#  {'video_id': '5x6WDB2NvFU',
#   'view_count': 44,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'ZHDhlbG3wXo',
#   'view_count': 454,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'mxIiqD43zDQ',
#   'view_count': 274,
#   'like_count': 7,
#   'comment_count': 2},
#  {'video_id': 'g3NF-T-2soI',
#   'view_count': 772,
#   'like_count': 19,
#   'comment_count': 6},
#  {'video_id': 'BgRmjnsMKtY',
#   'view_count': 34,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'NjhuzFXd0wM',
#   'view_count': 94,
#   'like_count': 5,
#   'comment_count': 12},
#  {'video_id': 'sY93xDZQ4YE',
#   'view_count': 12,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'oT9oAyx2X-o',
#   'view_count': 163,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'Ep2pJo2_DJc',
#   'view_count': 945,
#   'like_count': 8,
#   'comment_count': 1},
#  {'video_id': 'w7Sx_QNCekE',
#   'view_count': 9041,
#   'like_count': 241,
#   'comment_count': 26},
#  {'video_id': '2Lq_Z1NShk0',
#   'view_count': 323,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'YFrHg_dJr2E',
#   'view_count': 611,
#   'like_count': 13,
#   'comment_count': 1},
#  {'video_id': 'fCQ8ogMHSoo',
#   'view_count': 9491,
#   'like_count': 244,
#   'comment_count': 24},
#  {'video_id': 'JGy2MWYNOkM',
#   'view_count': 1239,
#   'like_count': 7,
#   'comment_count': 2},
#  {'video_id': 'PkjzHDGtabY',
#   'view_count': 1944,
#   'like_count': 29,
#   'comment_count': 8},
#  {'video_id': 'FL0t6YVQTjQ',
#   'view_count': 454,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'Px1YyTj1h9M',
#   'view_count': 4435,
#   'like_count': 87,
#   'comment_count': 10},
#  {'video_id': 'FE1XyEMB3ZQ',
#   'view_count': 35,
#   'like_count': 1,
#   'comment_count': 1},
#  {'video_id': 'PlVvToVNB74',
#   'view_count': 65,
#   'like_count': 5,
#   'comment_count': 0},
#  {'video_id': 'O1RpLwsGocc',
#   'view_count': 587,
#   'like_count': 8,
#   'comment_count': 0},
#  {'video_id': 'X9tDjQitINI',
#   'view_count': 12876,
#   'like_count': 314,
#   'comment_count': 79},
#  {'video_id': 'FCW-TWW2D7E',
#   'view_count': 1477,
#   'like_count': 14,
#   'comment_count': 3},
#  {'video_id': 'btGwImFBsQI',
#   'view_count': 1247,
#   'like_count': 9,
#   'comment_count': 8},
#  {'video_id': 'ZY9r6G5R0zg',
#   'view_count': 172,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'S7wl_8sTrAY',
#   'view_count': 128,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'qzsiknOQsZI',
#   'view_count': 185,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'j6kWsvZRamM',
#   'view_count': 10167,
#   'like_count': 249,
#   'comment_count': 39},
#  {'video_id': 'vus1x3IIaiI',
#   'view_count': 2061,
#   'like_count': 38,
#   'comment_count': 14},
#  {'video_id': 'JT5XTA2zjTU',
#   'view_count': 22246,
#   'like_count': 685,
#   'comment_count': 60},
#  {'video_id': 'zCtT6H7z-Nw',
#   'view_count': 1795,
#   'like_count': 0,
#   'comment_count': 14},
#  {'video_id': 'yf9h4BEf5JY',
#   'view_count': 288,
#   'like_count': 7,
#   'comment_count': 3},
#  {'video_id': 'YRLi0vPfenw',
#   'view_count': 90,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': '65i5lcc2SaU',
#   'view_count': 11234,
#   'like_count': 611,
#   'comment_count': 37},
#  {'video_id': 'nmQGNNxqL6k',
#   'view_count': 811,
#   'like_count': 16,
#   'comment_count': 1},
#  {'video_id': '8jYGILH-neo',
#   'view_count': 33,
#   'like_count': 2,
#   'comment_count': 2},
#  {'video_id': 'a0jXjt9yiyw',
#   'view_count': 6294,
#   'like_count': 159,
#   'comment_count': 46},
#  {'video_id': 'SM_Rnp5Njv8',
#   'view_count': 98,
#   'like_count': 1,
#   'comment_count': 1},
#  {'video_id': '_Ljuu4pciL8',
#   'view_count': 107,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': '595tErjXQ2c',
#   'view_count': 431,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'VSBOrFUh6-w',
#   'view_count': 1259,
#   'like_count': 19,
#   'comment_count': 1},
#  {'video_id': '8uJ5NPEkGrk',
#   'view_count': 3845,
#   'like_count': 48,
#   'comment_count': 44},
#  {'video_id': '3j9-ZWP6bb4',
#   'view_count': 1138,
#   'like_count': 14,
#   'comment_count': 0},
#  {'video_id': '_2MtytULvuI',
#   'view_count': 1954,
#   'like_count': 55,
#   'comment_count': 21},
#  {'video_id': 'Ph76vLnJftI',
#   'view_count': 191,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'daL1k4S0oYs',
#   'view_count': 401,
#   'like_count': 3,
#   'comment_count': 7},
#  {'video_id': 'REC-ns-Lfbo',
#   'view_count': 18677,
#   'like_count': 614,
#   'comment_count': 85},
#  {'video_id': 'k6LD9Gz8gA4',
#   'view_count': 4,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'IHeXLivuWY0',
#   'view_count': 8,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 's3cD09EMZgQ',
#   'view_count': 59,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'vp6GwDAZ0o4',
#   'view_count': 253,
#   'like_count': 28,
#   'comment_count': 3},
#  {'video_id': '_-2c_5QdR0Q',
#   'view_count': 18217,
#   'like_count': 937,
#   'comment_count': 107},
#  {'video_id': 'Bf4EY_knLg4',
#   'view_count': 560,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'fcSD2JO7_us',
#   'view_count': 525,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'RbZW51Y46ok',
#   'view_count': 1030,
#   'like_count': 12,
#   'comment_count': 2},
#  {'video_id': 'RMTpxzn3T2Q',
#   'view_count': 126,
#   'like_count': 2,
#   'comment_count': 4},
#  {'video_id': 'e2GCwCRIR-g',
#   'view_count': 469,
#   'like_count': 7,
#   'comment_count': 2},
#  {'video_id': '8Cl_JAo6JP8',
#   'view_count': 433,
#   'like_count': 24,
#   'comment_count': 6},
#  {'video_id': 'Ze7-n-TUaCk',
#   'view_count': 101,
#   'like_count': 4,
#   'comment_count': 5},
#  {'video_id': 'HtiQTlD6xzU',
#   'view_count': 4802,
#   'like_count': 44,
#   'comment_count': 8},
#  {'video_id': 'Gnw6yTpQlbE',
#   'view_count': 1580,
#   'like_count': 37,
#   'comment_count': 17},
#  {'video_id': 'ZQc5kypkUfo',
#   'view_count': 8117,
#   'like_count': 144,
#   'comment_count': 23},
#  {'video_id': 'kyH03cII71A',
#   'view_count': 1781,
#   'like_count': 23,
#   'comment_count': 1},
#  {'video_id': 'qBrrBqkN1kw',
#   'view_count': 3562,
#   'like_count': 55,
#   'comment_count': 0},
#  {'video_id': '3PYqoZCEMrc',
#   'view_count': 617,
#   'like_count': 18,
#   'comment_count': 10},
#  {'video_id': 'W-VdDWHTwCI',
#   'view_count': 133,
#   'like_count': 4,
#   'comment_count': 1},
#  {'video_id': 'eWiuf5o8zyQ',
#   'view_count': 5515,
#   'like_count': 134,
#   'comment_count': 12},
#  {'video_id': 'UXPsNO7v7tM',
#   'view_count': 45,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'r-G9DPlqU_U',
#   'view_count': 441,
#   'like_count': 7,
#   'comment_count': 4},
#  {'video_id': 'eRVBP8QsSZo',
#   'view_count': 703,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': '_wTVGHNqZM4',
#   'view_count': 740,
#   'like_count': 13,
#   'comment_count': 3},
#  {'video_id': '1IV9RUDm__w',
#   'view_count': 5134,
#   'like_count': 29,
#   'comment_count': 8},
#  {'video_id': 'Njk9zghqhLo',
#   'view_count': 215,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'b4Q9Bn7dfas',
#   'view_count': 137,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': '7Bsvr5si0yU',
#   'view_count': 1981,
#   'like_count': 27,
#   'comment_count': 2},
#  {'video_id': 'leDdjp_LQQc',
#   'view_count': 961,
#   'like_count': 3,
#   'comment_count': 4},
#  {'video_id': 'w8t4tdtIzYY',
#   'view_count': 145567,
#   'like_count': 5530,
#   'comment_count': 224},
#  {'video_id': 'qAwpM3eAG6E',
#   'view_count': 238,
#   'like_count': 5,
#   'comment_count': 0},
#  {'video_id': '-6fztSbmZJc',
#   'view_count': 149,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'P6TAzJCWR8s',
#   'view_count': 143,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'j77hkj_Pgrw',
#   'view_count': 35,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'hfiO-kM1j8A',
#   'view_count': 1610,
#   'like_count': 58,
#   'comment_count': 0},
#  {'video_id': 'iWg22jn4h0U',
#   'view_count': 6761,
#   'like_count': 194,
#   'comment_count': 97},
#  {'video_id': 'bHsH5o5-yw0',
#   'view_count': 24950,
#   'like_count': 1583,
#   'comment_count': 300},
#  {'video_id': 'kRoSPbaJ60c',
#   'view_count': 212,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': '2hasCzaXugw',
#   'view_count': 1290,
#   'like_count': 29,
#   'comment_count': 0},
#  {'video_id': 'XZyQAqvRH8U',
#   'view_count': 207,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'O5ucGbMIMGo',
#   'view_count': 1119,
#   'like_count': 9,
#   'comment_count': 2},
#  {'video_id': '0C5hxmqH6-A',
#   'view_count': 1885,
#   'like_count': 57,
#   'comment_count': 2},
#  {'video_id': 'X9wEcqOtxrc',
#   'view_count': 92,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'Bpz5DpjN4nk',
#   'view_count': 125,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'EG3wv9SAnAM',
#   'view_count': 5741,
#   'like_count': 96,
#   'comment_count': 9},
#  {'video_id': '-z6gZxp_i1o',
#   'view_count': 1392,
#   'like_count': 37,
#   'comment_count': 4},
#  {'video_id': 'LHWQP-8AEjA',
#   'view_count': 378,
#   'like_count': 8,
#   'comment_count': 0},
#  {'video_id': '_VpeZMvjhNQ',
#   'view_count': 11722,
#   'like_count': 81,
#   'comment_count': 6},
#  {'video_id': 'B7Amh9dWir0',
#   'view_count': 1861,
#   'like_count': 61,
#   'comment_count': 17},
#  {'video_id': 'BZ4aTQDJ28Q',
#   'view_count': 5728,
#   'like_count': 100,
#   'comment_count': 8},
#  {'video_id': 'nvwN3cyOzxI',
#   'view_count': 279,
#   'like_count': 8,
#   'comment_count': 0},
#  {'video_id': 'Y8KqSRXBS9M',
#   'view_count': 109,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'tI1Mb1whf7M',
#   'view_count': 31,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'cyeN0FUFilQ',
#   'view_count': 153,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'i8sZhvCLzkw',
#   'view_count': 1981,
#   'like_count': 22,
#   'comment_count': 7},
#  {'video_id': 'CzF8X4PJl50',
#   'view_count': 1176,
#   'like_count': 41,
#   'comment_count': 16},
#  {'video_id': '3ZcfbU8wflQ',
#   'view_count': 297,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'mtOSbhEryAg',
#   'view_count': 126,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'z6bZ60zfUZo',
#   'view_count': 1193,
#   'like_count': 5,
#   'comment_count': 0},
#  {'video_id': 'jbu-j8AHMls',
#   'view_count': 1367,
#   'like_count': 4,
#   'comment_count': 1},
#  {'video_id': 'hRHYZK9hQE8',
#   'view_count': 2430,
#   'like_count': 6,
#   'comment_count': 1},
#  {'video_id': 'XPPwI1hqdQw',
#   'view_count': 931,
#   'like_count': 54,
#   'comment_count': 12},
#  {'video_id': 'djQ5R6nyWtc',
#   'view_count': 813,
#   'like_count': 18,
#   'comment_count': 0},
#  {'video_id': '-Bz_DRgwGhY',
#   'view_count': 278,
#   'like_count': 4,
#   'comment_count': 1},
#  {'video_id': '9YZsL3O9Mgw',
#   'view_count': 2584,
#   'like_count': 35,
#   'comment_count': 4},
#  {'video_id': 'LPvDdHGyNbM',
#   'view_count': 6901,
#   'like_count': 51,
#   'comment_count': 4},
#  {'video_id': 'kJav161rpo0',
#   'view_count': 3380,
#   'like_count': 70,
#   'comment_count': 18},
#  {'video_id': 'v8K3M4inHHA',
#   'view_count': 2160,
#   'like_count': 17,
#   'comment_count': 9},
#  {'video_id': 'WxOlub-8xAQ',
#   'view_count': 1351,
#   'like_count': 4,
#   'comment_count': 2},
#  {'video_id': 'oOjVBigSrcg',
#   'view_count': 5200,
#   'like_count': 140,
#   'comment_count': 19},
#  {'video_id': 'rJe5IJsS_ho',
#   'view_count': 2457,
#   'like_count': 47,
#   'comment_count': 0},
#  {'video_id': 'iXszw7bSg6w',
#   'view_count': 1113,
#   'like_count': 17,
#   'comment_count': 7},
#  {'video_id': 'AgwhiHLu2H4',
#   'view_count': 91841,
#   'like_count': 2179,
#   'comment_count': 93},
#  {'video_id': 'pg1hmpwAVVo',
#   'view_count': 40205,
#   'like_count': 43,
#   'comment_count': 5},
#  {'video_id': 'rIpNhRiKICE',
#   'view_count': 196,
#   'like_count': 5,
#   'comment_count': 0},
#  {'video_id': 'Uj61r9GGqM4',
#   'view_count': 68,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'N3XHBTa1Pps',
#   'view_count': 35,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'BidmURbo4pY',
#   'view_count': 1794,
#   'like_count': 50,
#   'comment_count': 18},
#  {'video_id': 'XaR5tsGY1mg',
#   'view_count': 3046,
#   'like_count': 22,
#   'comment_count': 6},
#  {'video_id': 'qKTGXtWYFNY',
#   'view_count': 167,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'PhOAHfHS1j4',
#   'view_count': 819,
#   'like_count': 9,
#   'comment_count': 4},
#  {'video_id': 'XsFOdEvZjBM',
#   'view_count': 516,
#   'like_count': 12,
#   'comment_count': 3},
#  {'video_id': 'DsCcK2s6TwU',
#   'view_count': 1160,
#   'like_count': 8,
#   'comment_count': 1},
#  {'video_id': 'gfx8O8nqiR4',
#   'view_count': 4680,
#   'like_count': 53,
#   'comment_count': 5},
#  {'video_id': 'g7adPCetpa4',
#   'view_count': 85,
#   'like_count': 1,
#   'comment_count': 1},
#  {'video_id': 'sd3G7xRfijk',
#   'view_count': 181,
#   'like_count': 12,
#   'comment_count': 1},
#  {'video_id': 'ywZZuRUBonY',
#   'view_count': 3517,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'nv0pSOM46pM',
#   'view_count': 201,
#   'like_count': 0,
#   'comment_count': 1},
#  {'video_id': 'eH8AZ74r1zk',
#   'view_count': 195,
#   'like_count': 0,
#   'comment_count': 1},
#  {'video_id': '0ZI_KfUFzCQ',
#   'view_count': 403,
#   'like_count': 5,
#   'comment_count': 1},
#  {'video_id': 'QkfUqb2XFRw',
#   'view_count': 48954,
#   'like_count': 1020,
#   'comment_count': 72},
#  {'video_id': 'iOsH7aCxPwY',
#   'view_count': 13673,
#   'like_count': 74,
#   'comment_count': 4},
#  {'video_id': 'isoxDO3qWAU',
#   'view_count': 3865,
#   'like_count': 21,
#   'comment_count': 3},
#  {'video_id': 'Exg9UpHaaI4',
#   'view_count': 125,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'ltb4-tROtLk',
#   'view_count': 14892,
#   'like_count': 128,
#   'comment_count': 18},
#  {'video_id': '7ly-YKP3Syo',
#   'view_count': 74,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'DBADrF0C2ls',
#   'view_count': 28985,
#   'like_count': 638,
#   'comment_count': 74},
#  {'video_id': 'fWnbhsipfGA',
#   'view_count': 5314,
#   'like_count': 74,
#   'comment_count': 12},
#  {'video_id': 'UNAe7K4-Pvg',
#   'view_count': 2258,
#   'like_count': 13,
#   'comment_count': 1},
#  {'video_id': 'skJVaaCEots',
#   'view_count': 2637,
#   'like_count': 18,
#   'comment_count': 1},
#  {'video_id': '1vIGUdjVOFQ',
#   'view_count': 102,
#   'like_count': 1,
#   'comment_count': 0},
#  {'video_id': 'ly6I--LwqAU',
#   'view_count': 273,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'ZkwvgurJxPE',
#   'view_count': 545,
#   'like_count': 0,
#   'comment_count': 0},
#  {'video_id': 'X_-_t-4Qbzs',
#   'view_count': 354,
#   'like_count': 4,
#   'comment_count': 0},
#  {'video_id': 'G9w3YgEVYpo',
#   'view_count': 148,
#   'like_count': 3,
#   'comment_count': 0},
#  {'video_id': 'kK0w0dkyG3I',
#   'view_count': 2403,
#   'like_count': 20,
#   'comment_count': 6},
#  {'video_id': '9P03uuOIMWI',
#   'view_count': 1082,
#   'like_count': 6,
#   'comment_count': 0},
#  {'video_id': '8amLe4PsIEo',
#   'view_count': 681,
#   'like_count': 9,
#   'comment_count': 1},
#  {'video_id': 'Wn3soeXrVCs',
#   'view_count': 2523,
#   'like_count': 32,
#   'comment_count': 9},
#  {'video_id': 'xvxucs2h024',
#   'view_count': 161,
#   'like_count': 2,
#   'comment_count': 0},
#  {'video_id': 'ZD7_DvrS7ns',
#   'view_count': 642,
#   'like_count': 4,
#   'comment_count': 0}]

# %%
dfp_st = pd.DataFrame(dfp_st)

# %%
undf = dfp_st.merge(combined_df, on='video_id')

# %%
undf.head()
# Out:
#       video_id  view_count  like_count  comment_count  \
# 0  4rHvPy9vbM8         125           0              0
# 1  -rCi_gpWYcs         186           3              2
# 2  F4PV_P5mTNA         121           4              1
# 3  OVFAjzGDU5w        1716          67              2
# 4  szFUXInlifY         463          12              8
#
#                                                title  \
# 0                         Yandex Translate, tutorial
# 1  Yandex Datalens. Дашборд за 15 минут. Анализир...
# 2                Расширения Yii2: Урок 3. Yandex Map
# 3  Запускаем контейнерные приложения в Yandex Ser...
# 4  Оцифровка бизнеса на Wildberries на Yandex Dat...
#
#                                          description          published_at  \
# 0                                                     2023-03-17T16:11:24Z
# 1  В этом видео я рассказываю, как сделать дашбор...  2023-03-17T09:53:54Z
# 2  В этом уроке разберем, как вставить карту Янде...  2023-03-13T14:00:07Z
# 3  Современные разработчики всё чаще выбирают кон...  2023-02-14T09:53:03Z
# 4  Рассказываю как с использованием Yandex DataLe...  2023-02-06T12:51:41Z
#
#                cat_name
# 0        People & Blogs
# 1             Education
# 2             Education
# 3  Science & Technology
# 4        People & Blogs

# %% [markdown]
# **7. Обратите внимание на столбец `snippet.categoryId`, посмотрите на уникальные значения в нем.**
#
# *Это категория видео, нужно ее записать понятным нам языком.*

# %%
dfp_cat = []
for idv in undf['video_id']:
    response = youtube.videos().list(
        part='snippet',
        id=idv,
        fields='items(id,snippet(categoryId))'
    ).execute()
    cat = int(response['items'][0]['snippet']['categoryId'])
    dfp_cat.append(cat)

# %%
undf['cat_id'] = dfp_cat

# %%
cat_name = []
for category_id in undf['cat_id']:    
    category_response = youtube.videoCategories().list(part='snippet', id=category_id).execute()
    cat_name.append(category_response['items'][0]['snippet']['title'])
undf['cat_name'] = cat_name

# %%
undf.cat_name.value_counts()
# Out:
# Education                56
# People & Blogs           55
# Science & Technology     48
# Howto & Style             8
# Entertainment             6
# Gaming                    5
# Film & Animation          5
# Music                     4
# Comedy                    3
# Travel & Events           2
# News & Politics           1
# Autos & Vehicles          1
# Nonprofits & Activism     1
# Name: cat_name, dtype: int64

# %%
undf
# Out:
#         video_id  view_count  like_count  comment_count  \
# 0    uiIuGECFDBA         140           5              3
# 1    4rHvPy9vbM8          67           1              0
# 2    -rCi_gpWYcs         186           3              2
# 3    F4PV_P5mTNA         121           4              1
# 4    OVFAjzGDU5w        1716          67              2
# ..           ...         ...         ...            ...
# 216  IyV5tsN-dgQ        4595          24              2
# 217  gDx7_2Isrsw         167           1              0
# 218  DK3DZOppMbY         699           0              0
# 219  01DxB3GCX64         562           0              0
# 220  Mvj_AqOLy4k        5263           3              1
#
#                                                  title  \
# 0    База данных YDB в Yandex Cloud| Простой гайд д...
# 1                           Yandex Translate, tutorial
# 2    Yandex Datalens. Дашборд за 15 минут. Анализир...
# 3                  Расширения Yii2: Урок 3. Yandex Map
# 4    Запускаем контейнерные приложения в Yandex Ser...
# ..                                                 ...
# 216  Speed driving on yandex maps Chernobyl to Prip...
# 217             Загрузка нового сертификата Yandex.API
# 218                              Сертификат Yandex.API
# 219                                        yandex maps
# 220                           Пробки на maps.yandex.ru
#
#                                            description          published_at  \
# 0    databasemanagement #python #yandexcloud #ydb #...  2023-03-29T16:59:30Z
# 1                                                       2023-03-17T16:11:24Z
# 2    В этом видео я рассказываю, как сделать дашбор...  2023-03-17T09:53:54Z
# 3    В этом уроке разберем, как вставить карту Янде...  2023-03-13T14:00:07Z
# 4    Современные разработчики всё чаще выбирают кон...  2023-02-14T09:53:03Z
# ..                                                 ...                   ...
# 216                                Yandex street view.  2011-04-13T20:09:43Z
# 217            Загрузка нового сертификата Yandex.API.  2010-08-26T12:48:39Z
# 218                             Сертификат Yandex.API.  2010-08-26T07:15:52Z
# 219                                                     2010-08-06T11:05:51Z
# 220                          Пробки на maps.yandex.ru.  2009-08-01T07:30:30Z
#
#      cat_id
# 0        22
# 1        22
# 2        27
# 3        27
# 4        28
# ..      ...
# 216      19
# 217      27
# 218      27
# 219      24
# 220       2
#
# [221 rows x 8 columns]

# %% [markdown]
# **8. Уберите из таблицы ненужные, по вашему мнению, столбцы. Обоснуйте свое решение.**

# %%
# ваш код
undf.columns
# Out:
# Index(['video_id', 'view_count', 'like_count', 'comment_count', 'title',
#        'description', 'published_at', 'cat_name'],
#       dtype='object')

# %% [markdown]
# Следует убрать столбец с названием категорией или с его id, поскольку оба столбца дают нам информацию об одном и том же категории.
#
# Какой из них убрать зависит от задачи: нам может понадобится текстовое описание для визуального анализа и представления или численное значение для задач ML, например.

# %% [markdown]
# Допустим, нам нужен первый вариант. Избавимся от колонки с id.

# %%
undf.drop('cat_id', axis=1, inplace=True)

# %%
undf.head()
# Out:
#       video_id  view_count  like_count  comment_count  \
# 0  4rHvPy9vbM8         125           0              0
# 1  -rCi_gpWYcs         186           3              2
# 2  F4PV_P5mTNA         121           4              1
# 3  OVFAjzGDU5w        1716          67              2
# 4  szFUXInlifY         463          12              8
#
#                                                title  \
# 0                         Yandex Translate, tutorial
# 1  Yandex Datalens. Дашборд за 15 минут. Анализир...
# 2                Расширения Yii2: Урок 3. Yandex Map
# 3  Запускаем контейнерные приложения в Yandex Ser...
# 4  Оцифровка бизнеса на Wildberries на Yandex Dat...
#
#                                          description          published_at  \
# 0                                                     2023-03-17T16:11:24Z
# 1  В этом видео я рассказываю, как сделать дашбор...  2023-03-17T09:53:54Z
# 2  В этом уроке разберем, как вставить карту Янде...  2023-03-13T14:00:07Z
# 3  Современные разработчики всё чаще выбирают кон...  2023-02-14T09:53:03Z
# 4  Рассказываю как с использованием Yandex DataLe...  2023-02-06T12:51:41Z
#
#                cat_name
# 0        People & Blogs
# 1             Education
# 2             Education
# 3  Science & Technology
# 4        People & Blogs

# %% [markdown]
# **9. Сохраните получившуюуся табличку в формате .csv.**

# %%
undf.to_csv('youtube_api.csv')
